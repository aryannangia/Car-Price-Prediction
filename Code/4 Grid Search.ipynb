# %% [markdown]
# # Grid Search

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import ShuffleSplit
import used_cars

# %% [markdown]
# Import data.

# %%
df = pd.read_feather("../Datasets/used_cars_data_large.feather", 
                     used_cars.Info.columns).fillna(pd.NA)
df = used_cars.remove_null_rows(df, [
    'back_legroom', 'front_legroom', 'fuel_tank_volume', 'height', 'length', 
    'maximum_seating', 'width', 'body_type', 'fuel_type', 'transmission', 
    'wheel_system', 'engine_type', 'power', 'torque'
])
df.insert(df.shape[1]-1, "price", df.pop("price"))

# %%
X = pd.DataFrame(df.iloc[:, :-1])
y = pd.DataFrame(df.iloc[:, -1])["price"]

# %%
cv = ShuffleSplit(
    n_splits=5, test_size=0.1, random_state=0
)

# %% [markdown]
# ## Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import r2_score
from sklearn.pipeline import Pipeline

# %%
rfreg_pipe = used_cars.make_used_cars_pipeline(
    model=RandomForestRegressor(random_state=0), random_state=0, 
    final_cols=[
'powerRPM', 'savings_amount', 'torqueRPM', 'pca_fuel_economy_1', 
    'pca_engine_1', 'pca_car_usage_1', 'avg_car_space', 
    'franchise_make_encoded_1'
    ],
)

# %%
rfreg_param_grid = {
    "model__n_estimators": [10, 25, 50, 100, 125, 150, 175, 200],
    "model__max_samples": [0.5, 1.0],
}

# %%
rfreg_grid_search = GridSearchCV(
    rfreg_pipe, rfreg_param_grid, scoring=[
        "r2", "neg_mean_absolute_error", "neg_root_mean_squared_error", 
        "neg_mean_absolute_percentage_error"
    ], refit="r2", cv=cv, verbose=1, n_jobs=-1
)
rfreg_grid_search.fit(X, y)
rfreg_grid_search.best_params_
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\joblib\externals\loky\process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(

# %% [markdown]
# Pickle results.

# %%
import joblib

# %%
with open("../Output/grid_search_8_large.joblib", "wb") as f:
    joblib.dump(rfreg_grid_search, f)

# %%
rfreg_results = pd.DataFrame(rfreg_grid_search.cv_results_)

# %% [markdown]
# ## XGB Regressor

# %%
from xgboost import XGBRegressor

# %%
xgbreg_pipe = used_cars.make_used_cars_pipeline(
    model=XGBRegressor(random_state=0), random_state=0, 
    final_cols=[
'powerRPM', 'savings_amount', 'torqueRPM', 'pca_fuel_economy_1', 
    'pca_engine_1', 'pca_car_usage_1', 'avg_car_space', 
    'franchise_make_encoded_1'
    ],
)

# %%
xgbreg_param_grid = {
    "model__max_depth": [0, 5, 10, 20],
    "model__learning_rate": [0.1, 0.15, 0.2],
    "model__n_estimators": [10, 25, 50, 100, 125, 150],
}

# %%
xgbreg_grid_search = GridSearchCV(
    xgbreg_pipe, xgbreg_param_grid, scoring=[
        "r2", "neg_mean_absolute_error", "neg_root_mean_squared_error", 
        "neg_mean_absolute_percentage_error"
    ], refit="r2", cv=cv, verbose=1, n_jobs=-1
)
xgbreg_grid_search.fit(X, y)
xgbreg_grid_search.best_params_
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 180 fits failed out of a total of 720.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:22] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:23] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:24] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:25] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:26] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:27] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:28] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:29] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:30] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:31] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:32] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:33] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:34] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:35] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:36] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:37] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:38] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:39] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:40] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:41] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:42] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:44] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:45] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:46] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:47] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:48] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:51] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:11:50] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
# ...
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:20:33] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:20:34] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:20:35] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:20:36] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:20:37] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:20:38] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [20:20:39] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/tree/updater_colmaker.cc:177: Check failed: param_.max_depth > 0 (0 vs. 0) : exact tree method doesn't support unlimited depth.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#  0.34441631 0.77986962 0.83214341 0.85466659 0.86052343 0.86477304
#  0.4011381  0.8251929  0.86128444 0.86576236 0.86669702 0.86719206
#  0.40280771 0.82286828 0.85071485 0.85095847 0.85075151 0.85056837
#         nan        nan        nan        nan        nan        nan
#  0.63152544 0.81562376 0.84441501 0.86267062 0.86768835 0.87138278
#  0.68641091 0.85434214 0.86329286 0.86631159 0.86681135 0.86679063
#  0.69178202 0.84862647 0.85078393 0.85007955 0.84987448 0.84977017
#         nan        nan        nan        nan        nan        nan
#  0.74332899 0.83152859 0.85362056 0.869097   0.87330187 0.8758237
#  0.79254028 0.85826396 0.86354555 0.86557717 0.86580619 0.86568999
#  0.79081517 0.84773233 0.84791553 0.84733422 0.84722274 0.8471763 ]
#   warnings.warn(
# c:\Users\Gillbert\anaconda3\envs\sc1015\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: